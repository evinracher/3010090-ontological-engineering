# %% [markdown]
# <a href="https://colab.research.google.com/github/evinracher/3010090-ontological-engineering/blob/main/week2/part1/2_01_FundamentosLanchain_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 LangChain v1.0 con Gemini 2.5 Pro
# ## PromptTemplate, ChatModel y Chains
# Autor: Profesor Jaime Guzmán

# %%
from google.colab import userdata
import os

# Obtener la API key desde userdata
api_key = userdata.get('GOOGLE_API_KEY')

# Opcional: Guardarla como variable de entorno
os.environ['GOOGLE_API_KEY'] = api_key

# Verificar que se haya cargado correctamente
print("API Key cargada:", "Sí" if api_key else "No")
print("Primeros caracteres:", api_key[:10] if api_key else "No encontrada")
# Out:
# API Key cargada: Sí
# Primeros caracteres: AIzaSyDx4e

# %%
# =============================================================
# 🟦 1. Instalación y Configuración Inicial
# =============================================================
# !pip install "langchain>=1,<2" langchain-core langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# =============================================================
# 🟨 2. PromptTemplate: Plantillas dinámicas
# =============================================================
from langchain_core.prompts import PromptTemplate

# Crear plantilla con variable
plantilla_traduccion = PromptTemplate.from_template(
    """Traduce al español el siguiente texto: {texto}"""
)

# Usar la plantilla
prompt_generado = plantilla_traduccion.format(
    texto='Artificial intelligence is transforming education.'
)
print(prompt_generado)
# Out:
# Traduce al español el siguiente texto:
#
# Artificial intelligence is transforming education.

# %%
# =============================================================
# 🟩 3. ChatModel: Comunicación con gemini-2.5-flash-lite
# =============================================================

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage  # Importar desde langchain_core

#chat = ChatGoogleGenerativeAI(model='gemini-2.5-flash-exp', temperature=0.7)
chat = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite', temperature=0.7, google_api_key=api_key) # LLM


respuesta = chat.invoke([
    HumanMessage(content='Explica de forma sencilla qué es el aprendizaje profundo.')
])
print('\n🧠 Respuesta del modelo:\n', respuesta.content)
# Out:
# 🧠 Respuesta del modelo:
#  Imagina que quieres enseñarle a un ordenador a reconocer gatos en fotos.
#
# **Aprendizaje tradicional:** En el aprendizaje tradicional, tú tendrías que decirle al ordenador exactamente qué características buscar: "un gato tiene orejas puntiagudas, bigotes, una cola larga...". Sería como darle una lista de reglas muy detallada.
#
# **Aprendizaje profundo:** El aprendizaje profundo es diferente. En lugar de darle reglas específicas, le das al ordenador **un montón de fotos de gatos y un montón de fotos que NO son gatos**.
#
# Piensa en ello como darle al ordenador un cerebro con muchas capas (por eso se llama "profundo"). Cada capa aprende a reconocer algo un poco más complejo que la capa anterior.
#
# *   **Las primeras capas** podrían aprender a reconocer cosas muy básicas, como líneas y bordes.
# ...

# %%
# =============================================================
# 🟧 4. Chains: Uniendo Prompt + Modelo (Forma moderna LCEL)
# =============================================================

# Usar el operador | para encadenar (pipe operator)
cadena_traduccion = plantilla_traduccion | chat

# Invocar
resultado = cadena_traduccion.invoke({'texto': 'The quick brown fox jumps over the lazy dog.'})
print('\n🌍 Traducción generada por gemini-2.5-flash-lite:\n', resultado.content)
# Out:
# 🌍 Traducción generada por gemini-2.5-flash-lite:
#  La traducción al español de "The quick brown fox jumps over the lazy dog" es:
#
# **El rápido zorro marrón salta sobre el perro perezoso.**

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.runnables import RunnableSequence

# 1. Definir el modelo
chat = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# 2. Definir la plantilla
plantilla_traduccion = ChatPromptTemplate.from_template("Traduce al español el siguiente texto: {texto}")

# 3. Crear la cadena moderna
cadena_traduccion = RunnableSequence(plantilla_traduccion | chat) # Una nueva interface

# 4. Invocar la cadena
resultado = cadena_traduccion.invoke({"texto": "The quick brown fox jumps over the lazy dog."})
print("🌍 Traducción generada por Gemini:", resultado.content)
# Out:
# 🌍 Traducción generada por Gemini: La traducción al español de "The quick brown fox jumps over the lazy dog" es:
#
# **El rápido zorro marrón salta sobre el perro perezoso.**

# %%
# =============================================================
# 🟪 5. Ejercicio Integrador (versión moderna)
# =============================================================
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableSequence

# 1. Definir el modelo (asegúrate de tener la clave configurada)
chat = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# 2. Definir la plantilla de prompt
plantilla_tema = ChatPromptTemplate.from_template('''Explica el concepto de {tema} en tres partes:
1. Una explicación breve.
2. Un ejemplo práctico en Python.
3. Una pregunta reflexiva final.''')

# 3. Crear la "cadena" moderna con RunnableSequence
cadena_tema = RunnableSequence(plantilla_tema | chat)

# 4. Ejecutar el pipeline
salida = cadena_tema.invoke({"tema": "machine learning"})

# 5. Mostrar el resultado
print("📘 Resultado del ejercicio integrador:\n")
print(salida.content)
# Out:
# 📘 Resultado del ejercicio integrador:
#
# ¡Claro! Aquí tienes una explicación del Machine Learning dividida en tres partes:
#
# ## Machine Learning: Aprendiendo de los Datos
#
# ### 1. Explicación Breve
#
# El Machine Learning (ML), o Aprendizaje Automático, es una rama de la Inteligencia Artificial que permite a los sistemas informáticos **aprender de datos sin ser explícitamente programados**. En lugar de seguir un conjunto de instrucciones fijas para realizar una tarea, los algoritmos de ML utilizan **patrones y relaciones** encontrados en grandes cantidades de datos para **tomar decisiones o hacer predicciones**. Es como enseñar a un niño a reconocer un perro mostrándole muchas fotos de perros, en lugar de describirle detalladamente cómo es un perro. El sistema "aprende" a identificar las características comunes que definen a un perro.
#
# ### 2. Ejemplo Práctico en Python
#
# ...

# %% [markdown]
# ## 🟫 6. Reflexión Final
# ✅ LangChain v1.0 organiza la interacción con LLMs en tres componentes: PromptTemplate, ChatModel y Chains.
# - Usar Gemini 2.5 Pro permite aprovechar la potencia de los modelos de Google para tareas conversacionales y educativas.
# - La modularidad de LangChain facilita construir sistemas más grandes (retrievers, memoria, agentes, etc.).
